# %%
import matplotlib.pyplot as plt

# %%
sim = [33, 36, 31,27,
       53, 26, 161, 44, 34,169, 40,15,71,71,29,29,
       20,183,48,52,21,93,15,69,229,88,32,356,13,
       20,32,33,54,139,39,57,116,41,45,
       21,24,99,26,68,49,64,125,25,37,28,114,29,153,
       25,118,37,23,31,26,20,36,28,35,35,72,118,282,27,28,49]
exp = [76, 57, 251, 14, 16, 238, 29, 58, 31, 22, 10, 48, 47, 44, 34, 55, 10, 52, 46, 5, 19, 150, 25, 26, 25, 31, 42, 150, 250, 30, 11, 23, 43, 12, 14, 45, 261, 146, 15, 21, 18, 8, 13, 27, 9, 21, 29, 14, 161, 28, 154, 171, 121, 52, 47, 76, 78,  36, 34, 55, 17, 19, 21, 32, 76, 261, 28, 13]

plt.hist(sim, label = 'Simulation', alpha = 0.5, density = True)
plt.hist(exp, label = 'Experimental', alpha = 0.5, density = True)
plt.ylabel('Proportion')
plt.xlabel('Number of mutants')
plt.title('mu = 1E-6 (sic1∆)')
plt.legend()

sim = [3,0,1,1,1,1,3,0,6,1,1,1,1,0,2,5,3,11,1,4,0,4,32,3,11,0,32,1,3,0,5,5,2,0,33,1,0,4,1,2,0,2,1,5,0,14,4,8,67,2,0,0,18,0,1,0,1,17,0,1,1,0,2,4,13,12,1,2,2,2,3,1]
exp = [1, 2, 1, 16, 2, 3, 1, 10, 0, 0, 0, 0, 1, 5, 4, 2, 3, 1, 5, 1, 6, 2, 0, 0, 6, 8, 8, 2, 5, 0, 28, 2, 8, 1, 1, 2, 1, 1, 1, 7, 11, 1, 0, 0, 1, 2, 1, 3, 28, 0, 3, 12, 0, 0, 0, 0, 2, 1, 1, 51, 3, 0, 0, 2, 1, 0, 48, 2, 0, 0] 
plt.hist(sim, label = 'Simulation', alpha = 0.5, density = True)
plt.hist(exp, label = 'Experimental', alpha = 0.5, density = True)
plt.ylabel('Proportion')
plt.xlabel('Number of mutants')
plt.title('mu = 1E-7 (WT)')
plt.legend()
